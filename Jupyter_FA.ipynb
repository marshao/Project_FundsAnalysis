# %%
import C_Fund_Analysis as cf
import matplotlib.pyplot as plt
from matplotlib import style

style.use = 'ggplot'

fa = cf.C_Fund_Analysis()
df_nav = fa.readFundsNavFromCSV()
df_corr = fa.fundsCorr(df_nav.iloc[:, 0:30])
fa.plotCorrHeadMap(df_corr)

# %%
print df_nav
# Out:
#             000003_Nav  000004_Nav  000007_Nav  000014_Nav  000015_Nav  \
# 000003_Nav    0.036499    0.036660    0.002284   -0.004652   -0.004608
# 000004_Nav    0.036660    0.036831    0.002385   -0.004647   -0.004600
# 000007_Nav    0.002284    0.002385    0.001707    0.000266    0.000272
# 000014_Nav   -0.004652   -0.004647    0.000266    0.001024    0.000982
# 000015_Nav   -0.004608   -0.004600    0.000272    0.000982    0.001020
# 000016_Nav   -0.003884   -0.003869    0.000343    0.000867    0.000901
# 000024_Nav   -0.000858   -0.000694    0.001864    0.000578    0.000386
# 000025_Nav   -0.000726   -0.000553    0.001958    0.000573    0.000380
# 000045_Nav    0.002865    0.002976    0.001709    0.000184    0.000302
# 000046_Nav    0.003114    0.003223    0.001678    0.000131    0.000240
#
#             000016_Nav  000024_Nav  000025_Nav  000045_Nav  000046_Nav  \
# 000003_Nav   -0.003884   -0.000858   -0.000726    0.002865    0.003114
# 000004_Nav   -0.003869   -0.000694   -0.000553    0.002976    0.003223
# 000007_Nav    0.000343    0.001864    0.001958    0.001709    0.001678
# 000014_Nav    0.000867    0.000578    0.000573    0.000184    0.000131
# 000015_Nav    0.000901    0.000386    0.000380    0.000302    0.000240
# 000016_Nav    0.000806    0.000530    0.000534    0.000356    0.000302
# 000024_Nav    0.000530    0.009358    0.009561    0.000470    0.000518
# 000025_Nav    0.000534    0.009561    0.009775    0.000558    0.000606
# 000045_Nav    0.000356    0.000470    0.000558    0.002424    0.002349
# 000046_Nav    0.000302    0.000518    0.000606    0.002349    0.002282
#
#                ...      690202_Nav  690206_Nav  700005_Nav  700006_Nav  \
# 000003_Nav     ...        0.002900   -0.001169   -0.004407   -0.003482
# 000004_Nav     ...        0.002996   -0.001119   -0.004366   -0.003432
# 000007_Nav     ...        0.001573    0.000933    0.000716    0.000801
# 000014_Nav     ...        0.000778    0.000980    0.001237    0.001085
# 000015_Nav     ...        0.000774    0.000995    0.001299    0.001144
# 000016_Nav     ...        0.000749    0.000909    0.001154    0.001028
# 000024_Nav     ...        0.001569    0.000952    0.000481    0.000648
# 000025_Nav     ...        0.001596    0.000957    0.000481    0.000659
# 000045_Nav     ...        0.001560    0.000924    0.000992    0.001057
# 000046_Nav     ...        0.001525    0.000872    0.000899    0.000973
#
#             710301_Nav  710302_Nav  720002_Nav  720003_Nav  750002_Nav  \
# 000003_Nav    0.024987    0.025375    0.007311    0.000242   -0.004135
# 000004_Nav    0.025198    0.025590    0.007311    0.000318   -0.004190
# 000007_Nav    0.002574    0.002607    0.000173    0.001058   -0.000433
# 000014_Nav   -0.002647   -0.002727   -0.001107    0.000639    0.000657
# 000015_Nav   -0.002462   -0.002546   -0.001119    0.000666    0.000650
# 000016_Nav   -0.001980   -0.002049   -0.000962    0.000628    0.000525
# 000024_Nav   -0.000339   -0.000227   -0.000408    0.000925   -0.000840
# 000025_Nav   -0.000193   -0.000074   -0.000401    0.000953   -0.000899
# 000045_Nav    0.003289    0.003302    0.000038    0.001248   -0.000467
# 000046_Nav    0.003405    0.003424    0.000114    0.001200   -0.000500
#
#             750003_Nav
# 000003_Nav   -0.003255
# 000004_Nav   -0.003301
# 000007_Nav   -0.000347
# 000014_Nav    0.000516
# 000015_Nav    0.000507
# 000016_Nav    0.000410
# 000024_Nav   -0.000694
# 000025_Nav   -0.000741
# 000045_Nav   -0.000390
# 000046_Nav   -0.000415
#
# [10 rows x 373 columns]
